# %% [markdown]
# # Descriptive statistics-EXAMPLE 0
# Omar Fernando Arias Reinoso
#
# Tec

# %% [markdown]
# ## 0. Import the libraries

# %%
import pandas as pd

# %% [markdown]
# [Documentation of Pandas](https://pandas.pydata.org/docs/reference/)

# %% [markdown]
# ## 1. Import the database

# %% [markdown]
# [Upload excel files](https://pandas.pydata.org/docs/reference/api/pandas.read_excel.html)

# %%
db=pd.read_excel("grades.xlsx")
db
# Out:
#          name  math  statistics scholarship
# 0        Liam  10.0         5.0         yes
# 1      Olivia   8.0         7.0          no
# 2        Noah   6.0         6.0          no
# 3        Emma   7.0         NaN         yes
# 4     Olivier   5.0         7.0          no
# 5   Charlotte   7.0         7.0          no
# 6       James   5.0         6.0         yes
# 7      Amelia   NaN         7.0          no
# 8     William   7.0         8.0         yes
# 9      Sophia  10.0         6.0          no
# 10       Levi   7.0         8.0          no
# 11     Camila   6.0         8.0         yes

# %% [markdown]
# ## 2. Descriptive statistics

# %% [markdown]
# [Mean](https://pandas.pydata.org/docs/reference/api/pandas.Series.mean.html)

# %%
db.mean()
# Out:
# <ipython-input-4-04198dc263ed>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   db.mean()
# math          7.090909
# statistics    6.818182
# dtype: float64

# %%
mean_math=db["math"].mean()
print("The average person of the course obtain in math", mean_math, "points")
# Out:
# The average person of the course obtain in math 7.090909090909091 points

# %%
mean_statistics=db["statistics"].mean()
print("The average person of the course obtain in statistics", mean_statistics, "points")
# Out:
# The average person of the course obtain in statistics 6.818181818181818 points

# %%
db["average"]=(db["math"]+db["statistics"])/2
db
# Out:
#          name  math  statistics scholarship  average
# 0        Liam  10.0         5.0         yes      7.5
# 1      Olivia   8.0         7.0          no      7.5
# 2        Noah   6.0         6.0          no      6.0
# 3        Emma   7.0         NaN         yes      NaN
# 4     Olivier   5.0         7.0          no      6.0
# 5   Charlotte   7.0         7.0          no      7.0
# 6       James   5.0         6.0         yes      5.5
# 7      Amelia   NaN         7.0          no      NaN
# 8     William   7.0         8.0         yes      7.5
# 9      Sophia  10.0         6.0          no      8.0
# 10       Levi   7.0         8.0          no      7.5
# 11     Camila   6.0         8.0         yes      7.0

# %% [markdown]
# [Median](https://pandas.pydata.org/docs/reference/api/pandas.Series.median.html)

# %%
db.median()
# Out:
# <ipython-input-12-f40d31c5df55>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   db.median()
# math          7.00
# statistics    7.00
# average       7.25
# dtype: float64

# %%
db["math"].median()
# Out:
# 7.0

# %%
db["statistics"].median()
# Out:
# 7.0

# %%
db["physics"].median()
# Out:
# 7.0

# %% [markdown]
# [Mode](https://pandas.pydata.org/docs/reference/api/pandas.Series.mode.html)

# %%
db["math"].mode()
# Out:
# 0    7
# Name: math, dtype: int64

# %%
db["statistics"].mode()
# Out:
# 0    7
# Name: statistics, dtype: int64

# %%
db["physics"].mode()
# Out:
# 0    7
# Name: physics, dtype: int64

# %% [markdown]
# [Variance](https://pandas.pydata.org/docs/reference/api/pandas.Series.var.html)

# %%
db.var()
# Out:
# <ipython-input-98-3c069a151f75>:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   db.var()
# math          2.696970
# statistics    1.719697
# physics       3.659091
# dtype: float64

# %%
db["math"].var()
# Out:
# 2.6969696969696972

# %%
db["statistics"].var()
# Out:
# 1.7196969696969697

# %%
db["physics"].var()
# Out:
# 3.659090909090909

# %% [markdown]
# [Standard deviation](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.std.html)

# %%
db.std()
# Out:
# <ipython-input-102-c6ec16309607>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   db.std()
# math          1.642245
# statistics    1.311372
# physics       1.912875
# dtype: float64

# %%
db["math"].std()
# Out:
# 1.6422453217986943

# %% [markdown]
# [skewness](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.skew.html)

# %%
db.skew()
# Out:
# <ipython-input-104-34bb88cd8785>:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   db.skew()
# math          0.569240
# statistics    0.689999
# physics       0.414972
# dtype: float64

# %%
db["math"].skew()
# Out:
# 0.5692398378399811

# %%
db["statistics"].skew()
# Out:
# 0.6899992506303039

# %%
db["physics"].skew()
# Out:
# 0.41497160259520915

# %% [markdown]
# [Kurtosis](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.kurtosis.html)

# %%
db.kurtosis()
# Out:
# <ipython-input-108-81db18d428ad>:1: FutureWarning: The default value of numeric_only in DataFrame.kurt is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   db.kurtosis()
# math         -0.184977
# statistics    1.159409
# physics      -1.076533
# dtype: float64

# %%
db["math"].kurtosis()
# Out:
# -0.18497664436308714

# %%
db["physics"].kurtosis()
# Out:
# -1.0765325411828246

# %% [markdown]
# [Max](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.max.html)

# %%
db["math"].max()
# Out:
# 10

# %%
db["statistics"].max()
# Out:
# 10

# %%
db["physics"].max()
# Out:
# 10

# %% [markdown]
# [Min](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.min.html)

# %%
db["math"].min()
# Out:
# 5

# %%
db["statistics"].min()
# Out:
# 5

# %%
db["physics"].min()
# Out:
# 5

# %%
range_math=db["math"].max()-db["math"].min()
range_math
# Out:
# 5

# %%
range_physics=db["physics"].max()-db["physics"].min()
range_physics
# Out:
# 5

# %% [markdown]
# [Quantile](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.quantile.html)

# %% [markdown]
# 1.   Minimum value
# 2.   Q1-Lower quartile
# 3.   Median
# 4.   Q3-Upper quartile
# 5.   Maximum value

# %% [markdown]
# Quantiles divide the variable in four organized parts

# %%
Q1=db["math"].quantile(0.25)
Q1
# Out:
# 6.0

# %%
Q2=db["math"].quantile(0.5)
Q2
# Out:
# 7.0

# %%
Q3=db["math"].quantile(0.75)
Q3
# Out:
# 8.0

# %%
Q1_statistics=db["statistics"].quantile(0.25)
Q1_statistics
# Out:
# 6.0

# %%
Q1_physics=db["physics"].quantile(0.25)
Q1_physics
# Out:
# 5.75

# %%
Q3_physics=db["physics"].quantile(0.75)
Q3_physics
# Out:
# 8.5

# %%
P40_math=db["math"].quantile(0.40)
P40_math
# Out:
# 7.0

# %% [markdown]
# Quantile function of Pandas organizes all of the information in different rankes; for instance, Quantile(40%)=7 if you get 7 then you are above the 40% of the students i.e you are in the top 60% of the class.

# %%
IQR=Q3-Q1
IQR
# Out:
# 2.0

# %% [markdown]
# Graphs of descriptive statistics

# %% [markdown]
# [Box Plot](https://pandas.pydata.org/docs/reference/api/pandas.plotting.boxplot.html)

# %%
db.boxplot(column="math")
# Out:
# <Axes: >

# %% [markdown]
# In the box the information is organized in quartiles (4 different parts) and the lines are the whiskers the smallest and the highest numbers. 5 is the lowest grade in math. 10 is the highest grade in math. 6 is the first quartile (if you get 6 you are above 25% of the grades) 7 is the second quartile (if you get 7 you are above the 50%) 8 is the third quartile (if you get 7 you are above 75% of the population and you are at the top 25%)

# %%
db.boxplot(column="statistics")
# Out:
# <Axes: >

# %%
db.boxplot(column="physics")
# Out:
# <Axes: >

# %% [markdown]
# [Histogram](https://pandas.pydata.org/docs/reference/api/pandas.Series.plot.hist.html#pandas.Series.plot.hist)

# %%
db["math"].hist()
# Out:
# <Axes: >

# %%
db["statistics"].hist()
# Out:
# <Axes: >

# %%
db["physics"].hist()
# Out:
# <Axes: >

# %% [markdown]
# [Matplotlib](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.axvline.html://) (https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist.html)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(9,4))

plt.hist(db["math"],bins=10,color="cornflowerblue")

plt.axvline(db["math"].mean(),color="red",label="Mean")
plt.axvline(db["math"].median(),color="yellow",label="Median")
plt.axvline(db["math"].mode()[0],color="green",label="Mode")

plt.xlabel("Math")
plt.ylabel("Frequency")
plt.legend()
plt.show()

# %% [markdown]
# ## 3. Modifying the database

# %% [markdown]
# ### 3.1 Direct modification

# %%
db["average"]=(db["math"]+db["statistics"]+db["physics"])/3
db
# Out:
#          name  math  statistics  physics   average
# 0        Liam    10           5       10  8.333333
# 1      Olivia     8           7        7  7.333333
# 2        Noah     6           6        5  5.666667
# 3        Emma     7          10        7  8.000000
# 4     Olivier     5           7       10  7.333333
# 5   Charlotte     7           7        8  7.333333
# 6       James     5           6        5  5.333333
# 7      Amelia     8           7        7  7.333333
# 8     William     7           8        6  7.000000
# 9      Sophia    10           6        5  7.000000
# 10       Levi     7           8        7  7.333333
# 11     Camila     6           8       10  8.000000

# %%
db["average2"]=(db["math"]+db["statistics"])/2
db
# Out:
#          name  math  statistics  physics   average  average2
# 0        Liam    10           5       10  8.333333       7.5
# 1      Olivia     8           7        7  7.333333       7.5
# 2        Noah     6           6        5  5.666667       6.0
# 3        Emma     7          10        7  8.000000       8.5
# 4     Olivier     5           7       10  7.333333       6.0
# 5   Charlotte     7           7        8  7.333333       7.0
# 6       James     5           6        5  5.333333       5.5
# 7      Amelia     8           7        7  7.333333       7.5
# 8     William     7           8        6  7.000000       7.5
# 9      Sophia    10           6        5  7.000000       8.0
# 10       Levi     7           8        7  7.333333       7.5
# 11     Camila     6           8       10  8.000000       7.0

# %% [markdown]
# [Round](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.round.html)

# %%
db["average"]=round((db["math"]+db["statistics"]+db["physics"])/3)
db
# Out:
#          name  math  statistics  physics  average  average2
# 0        Liam    10           5       10      8.0       7.5
# 1      Olivia     8           7        7      7.0       7.5
# 2        Noah     6           6        5      6.0       6.0
# 3        Emma     7          10        7      8.0       8.5
# 4     Olivier     5           7       10      7.0       6.0
# 5   Charlotte     7           7        8      7.0       7.0
# 6       James     5           6        5      5.0       5.5
# 7      Amelia     8           7        7      7.0       7.5
# 8     William     7           8        6      7.0       7.5
# 9      Sophia    10           6        5      7.0       8.0
# 10       Levi     7           8        7      7.0       7.5
# 11     Camila     6           8       10      8.0       7.0

# %% [markdown]
# ### 3.2 Conditional modification

# %%
db["status1"]=["pass" if s>5 else "fail" for s in db["average"]]
db
# Out:
#          name  math  statistics  physics  average  average2 status1
# 0        Liam    10           5       10      8.0       7.5    pass
# 1      Olivia     8           7        7      7.0       7.5    pass
# 2        Noah     6           6        5      6.0       6.0    pass
# 3        Emma     7          10        7      8.0       8.5    pass
# 4     Olivier     5           7       10      7.0       6.0    pass
# 5   Charlotte     7           7        8      7.0       7.0    pass
# 6       James     5           6        5      5.0       5.5    fail
# 7      Amelia     8           7        7      7.0       7.5    pass
# 8     William     7           8        6      7.0       7.5    pass
# 9      Sophia    10           6        5      7.0       8.0    pass
# 10       Levi     7           8        7      7.0       7.5    pass
# 11     Camila     6           8       10      8.0       7.0    pass

# %%
import numpy as np
db['status1.1'] = np.where(db['status1'] == "pass", 1, 0)
db
# Out:
#          name  math  statistics  physics  average  average2 status1  status1.1
# 0        Liam    10           5       10      8.0       7.5    pass          1
# 1      Olivia     8           7        7      7.0       7.5    pass          1
# 2        Noah     6           6        5      6.0       6.0    pass          1
# 3        Emma     7          10        7      8.0       8.5    pass          1
# 4     Olivier     5           7       10      7.0       6.0    pass          1
# 5   Charlotte     7           7        8      7.0       7.0    pass          1
# 6       James     5           6        5      5.0       5.5    fail          0
# 7      Amelia     8           7        7      7.0       7.5    pass          1
# 8     William     7           8        6      7.0       7.5    pass          1
# 9      Sophia    10           6        5      7.0       8.0    pass          1
# 10       Levi     7           8        7      7.0       7.5    pass          1
# ...

# %%
db.boxplot()
# Out:
# <Axes: >

# %%
db.boxplot(by="status1")
# Out:
# array([[<Axes: title={'center': 'average'}, xlabel='[status1]'>,
#         <Axes: title={'center': 'average2'}, xlabel='[status1]'>],
#        [<Axes: title={'center': 'math'}, xlabel='[status1]'>,
#         <Axes: title={'center': 'physics'}, xlabel='[status1]'>],
#        [<Axes: title={'center': 'statistics'}, xlabel='[status1]'>,
#         <Axes: title={'center': 'status1.1'}, xlabel='[status1]'>]],
#       dtype=object)

# %%
db.boxplot(column="math",by="status1")
# Out:
# <Axes: title={'center': 'math'}, xlabel='status1'>

# %%
db["status3"]=["Good at Quant" if s>7 else "Bad at Quant" for s in db["average2"]]
db
# Out:
#          name  math  statistics  physics  average  average2 status1  \
# 0        Liam    10           5       10      8.0       7.5    pass
# 1      Olivia     8           7        7      7.0       7.5    pass
# 2        Noah     6           6        5      6.0       6.0    pass
# 3        Emma     7          10        7      8.0       8.5    pass
# 4     Olivier     5           7       10      7.0       6.0    pass
# 5   Charlotte     7           7        8      7.0       7.0    pass
# 6       James     5           6        5      5.0       5.5    fail
# 7      Amelia     8           7        7      7.0       7.5    pass
# 8     William     7           8        6      7.0       7.5    pass
# 9      Sophia    10           6        5      7.0       8.0    pass
# 10       Levi     7           8        7      7.0       7.5    pass
# 11     Camila     6           8       10      8.0       7.0    pass
#
#     status1.1        status3
# 0           1  Good at Quant
# ...

# %%
def status2(row):  
    if row["average"] == 5:
        return 'fail'
    elif row["average"] == 6 or row["average"] == 7:
        return 'Sufficient'
    elif row["average"] == 8 or row["average"] ==9:
        return "good"
    return "excellent"

# %%
db['status2'] = db.apply(lambda row: status2(row), axis=1)
db
# Out:
#          name  math  statistics  physics  average  average2 status1  \
# 0        Liam    10           5       10      8.0       7.5    pass
# 1      Olivia     8           7        7      7.0       7.5    pass
# 2        Noah     6           6        5      6.0       6.0    pass
# 3        Emma     7          10        7      8.0       8.5    pass
# 4     Olivier     5           7       10      7.0       6.0    pass
# 5   Charlotte     7           7        8      7.0       7.0    pass
# 6       James     5           6        5      5.0       5.5    fail
# 7      Amelia     8           7        7      7.0       7.5    pass
# 8     William     7           8        6      7.0       7.5    pass
# 9      Sophia    10           6        5      7.0       8.0    pass
# 10       Levi     7           8        7      7.0       7.5    pass
# 11     Camila     6           8       10      8.0       7.0    pass
#
#     status1.1        status3     status2
# ...

# %%
#def categorise(row):  
#    if row['average'] > 5 and row['average'] <= 7:
#        return 'A'
#    elif row['average'] > 7 and row['average'] <= 9:
#        return 'B'
#    elif row['average'] > 9  and row['average'] <= 10:
#        return 'C'
#    return 'D'

# %% [markdown]
# ### 3.3 Deleting columns or rows

# %% [markdown]
# Deleting rows (status2)

# %%
db
# Out:
#          name  math  statistics  physics  average  average2 status1  \
# 0        Liam    10           5       10      8.0       7.5    pass
# 1      Olivia     8           7        7      7.0       7.5    pass
# 2        Noah     6           6        5      6.0       6.0    pass
# 3        Emma     7          10        7      8.0       8.5    pass
# 4     Olivier     5           7       10      7.0       6.0    pass
# 5   Charlotte     7           7        8      7.0       7.0    pass
# 6       James     5           6        5      5.0       5.5    fail
# 7      Amelia     8           7        7      7.0       7.5    pass
# 8     William     7           8        6      7.0       7.5    pass
# 9      Sophia    10           6        5      7.0       8.0    pass
# 10       Levi     7           8        7      7.0       7.5    pass
# 11     Camila     6           8       10      8.0       7.0    pass
#
#     status1.1        status3     status2
# ...

# %%
db.drop(["status2"],axis=1)
# Out:
#          name  math  statistics  physics  average  average2 status1  \
# 0        Liam    10           5       10      8.0       7.5    pass
# 1      Olivia     8           7        7      7.0       7.5    pass
# 2        Noah     6           6        5      6.0       6.0    pass
# 3        Emma     7          10        7      8.0       8.5    pass
# 4     Olivier     5           7       10      7.0       6.0    pass
# 5   Charlotte     7           7        8      7.0       7.0    pass
# 6       James     5           6        5      5.0       5.5    fail
# 7      Amelia     8           7        7      7.0       7.5    pass
# 8     William     7           8        6      7.0       7.5    pass
# 9      Sophia    10           6        5      7.0       8.0    pass
# 10       Levi     7           8        7      7.0       7.5    pass
# 11     Camila     6           8       10      8.0       7.0    pass
#
#     status1.1        status3
# 0           1  Good at Quant
# ...

# %%
db.drop(["physics"],axis=1)
# Out:
#          name  math  statistics  average  average2 status1  status1.1  \
# 0        Liam    10           5      8.0       7.5    pass          1
# 1      Olivia     8           7      7.0       7.5    pass          1
# 2        Noah     6           6      6.0       6.0    pass          1
# 3        Emma     7          10      8.0       8.5    pass          1
# 4     Olivier     5           7      7.0       6.0    pass          1
# 5   Charlotte     7           7      7.0       7.0    pass          1
# 6       James     5           6      5.0       5.5    fail          0
# 7      Amelia     8           7      7.0       7.5    pass          1
# 8     William     7           8      7.0       7.5    pass          1
# 9      Sophia    10           6      7.0       8.0    pass          1
# 10       Levi     7           8      7.0       7.5    pass          1
# 11     Camila     6           8      8.0       7.0    pass          1
#
#           status3     status2
# ...

# %% [markdown]
# Deleting columns (Olivier)

# %%
db.drop(4,axis=0)
# Out:
#          name  math  statistics  physics  average  average2 status1  \
# 0        Liam    10           5       10      8.0       7.5    pass
# 1      Olivia     8           7        7      7.0       7.5    pass
# 2        Noah     6           6        5      6.0       6.0    pass
# 3        Emma     7          10        7      8.0       8.5    pass
# 5   Charlotte     7           7        8      7.0       7.0    pass
# 6       James     5           6        5      5.0       5.5    fail
# 7      Amelia     8           7        7      7.0       7.5    pass
# 8     William     7           8        6      7.0       7.5    pass
# 9      Sophia    10           6        5      7.0       8.0    pass
# 10       Levi     7           8        7      7.0       7.5    pass
# 11     Camila     6           8       10      8.0       7.0    pass
#
#     status1.1        status3     status2
# 0           1  Good at Quant        good
# 1           1  Good at Quant  Sufficient
# ...

# %%
db.drop(1,axis=0)
# Out:
#          name  math  statistics  physics  average  average2 status1  \
# 0        Liam    10           5       10      8.0       7.5    pass
# 2        Noah     6           6        5      6.0       6.0    pass
# 3        Emma     7          10        7      8.0       8.5    pass
# 4     Olivier     5           7       10      7.0       6.0    pass
# 5   Charlotte     7           7        8      7.0       7.0    pass
# 6       James     5           6        5      5.0       5.5    fail
# 7      Amelia     8           7        7      7.0       7.5    pass
# 8     William     7           8        6      7.0       7.5    pass
# 9      Sophia    10           6        5      7.0       8.0    pass
# 10       Levi     7           8        7      7.0       7.5    pass
# 11     Camila     6           8       10      8.0       7.0    pass
#
#     status1.1        status3     status2
# 0           1  Good at Quant        good
# 2           1   Bad at Quant  Sufficient
# ...

# %% [markdown]
# Modifiying one observation (Camila=Alisha)

# %%
db.at[11,"name"]="Alisha"
db
# Out:
#          name  math  statistics  physics  average  average2 status1  \
# 0        Liam    10           5       10      8.0       7.5    pass
# 1      Olivia     8           7        7      7.0       7.5    pass
# 2        Noah     6           6        5      6.0       6.0    pass
# 3        Emma     7          10        7      8.0       8.5    pass
# 4     Olivier     5           7       10      7.0       6.0    pass
# 5   Charlotte     7           7        8      7.0       7.0    pass
# 6       James     5           6        5      5.0       5.5    fail
# 7      Amelia     8           7        7      7.0       7.5    pass
# 8     William     7           8        6      7.0       7.5    pass
# 9      Sophia    10           6        5      7.0       8.0    pass
# 10       Levi     7           8        7      7.0       7.5    pass
# 11     Alisha     6           8       10      8.0       7.0    pass
#
#     status1.1        status3     status2
# ...

# %%
db2=db.rename(columns={"status2":"statusb"})
db2
# Out:
#          name  math  statistics  physics  average  average2 status1  \
# 0        Liam    10           5       10      8.0       7.5    pass
# 1      Olivia     8           7        7      7.0       7.5    pass
# 2        Noah     6           6        5      6.0       6.0    pass
# 3        Emma     7          10        7      8.0       8.5    pass
# 4     Olivier     5           7       10      7.0       6.0    pass
# 5   Charlotte     7           7        8      7.0       7.0    pass
# 6       James     5           6        5      5.0       5.5    fail
# 7      Amelia     8           7        7      7.0       7.5    pass
# 8     William     7           8        6      7.0       7.5    pass
# 9      Sophia    10           6        5      7.0       8.0    pass
# 10       Levi     7           8        7      7.0       7.5    pass
# 11     Alisha     6           8       10      8.0       7.0    pass
#
#     status1.1        status3     statusb
# ...

# %%
db3=db.rename(columns={"status3":"statusc"})
db3
# Out:
#          name  math  statistics  physics  average  average2 status1  \
# 0        Liam    10           5       10      8.0       7.5    pass
# 1      Olivia     8           7        7      7.0       7.5    pass
# 2        Noah     6           6        5      6.0       6.0    pass
# 3        Emma     7          10        7      8.0       8.5    pass
# 4     Olivier     5           7       10      7.0       6.0    pass
# 5   Charlotte     7           7        8      7.0       7.0    pass
# 6       James     5           6        5      5.0       5.5    fail
# 7      Amelia     8           7        7      7.0       7.5    pass
# 8     William     7           8        6      7.0       7.5    pass
# 9      Sophia    10           6        5      7.0       8.0    pass
# 10       Levi     7           8        7      7.0       7.5    pass
# 11     Alisha     6           8       10      8.0       7.0    pass
#
#     status1.1        statusc     status2
# ...

# %% [markdown]
# ### 3.4 Scatter plots

# %%
db.plot.scatter(x="math",y="physics",title="Physics vs math",color="red")
# Out:
# <Axes: title={'center': 'Physics vs math'}, xlabel='math', ylabel='physics'>

# %% [markdown]
# ### 3.4 Exporting excel files

# %% [markdown]
# [Export to excel](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_excel.html)

# %%
db.to_excel("grades_f.xlsx")

# %%
db3.to_excel("grades_f2.xlsx")

# %% [markdown]
# ## 4. Descriptive statistics with grouped variables

# %% [markdown]
# [groupby](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.groupby.html)

# %%
grouped_1=db.groupby("status1")

# %%
db3
# Out:
#          name  math  statistics  physics  average  average2 status1  \
# 0        Liam    10           5       10      8.0       7.5    pass
# 1      Olivia     8           7        7      7.0       7.5    pass
# 2        Noah     6           6        5      6.0       6.0    pass
# 3        Emma     7          10        7      8.0       8.5    pass
# 4     Olivier     5           7       10      7.0       6.0    pass
# 5   Charlotte     7           7        8      7.0       7.0    pass
# 6       James     5           6        5      5.0       5.5    fail
# 7      Amelia     8           7        7      7.0       7.5    pass
# 8     William     7           8        6      7.0       7.5    pass
# 9      Sophia    10           6        5      7.0       8.0    pass
# 10       Levi     7           8        7      7.0       7.5    pass
# 11     Alisha     6           8       10      8.0       7.0    pass
#
#     status1.1        statusc     status2
# ...

# %%
grouped_2=db3.groupby("statusc")
grouped_2.describe()
# Out:
#                math                                               statistics  \
#               count      mean       std  min  25%  50%  75%   max      count
# statusc
# Bad at Quant    5.0  5.800000  0.836660  5.0  5.0  6.0  6.0   7.0        5.0
# Good at Quant   7.0  8.142857  1.345185  7.0  7.0  8.0  9.0  10.0        7.0
#
#                          ... average2      status1.1                           \
#                    mean  ...      75%  max     count mean       std  min  25%
# statusc                  ...
# Bad at Quant   6.800000  ...     7.00  7.0       5.0  0.8  0.447214  0.0  1.0
# Good at Quant  7.285714  ...     7.75  8.5       7.0  1.0  0.000000  1.0  1.0
#
#
#                50%  75%  max
# statusc
# Bad at Quant   1.0  1.0  1.0
# Good at Quant  1.0  1.0  1.0
#
# [2 rows x 48 columns]

# %% [markdown]
# [Value counts](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.value_counts.html)

# %%
grouped_1.value_counts()
# Out:
# status1  name       math  statistics  physics  average  average2  status1.1  status3        status2
# fail     James      5     6           5        5.0      5.5       0          Bad at Quant   fail          1
# pass     Alisha     6     8           10       8.0      7.0       1          Bad at Quant   good          1
#          Amelia     8     7           7        7.0      7.5       1          Good at Quant  Sufficient    1
#          Charlotte  7     7           8        7.0      7.0       1          Bad at Quant   Sufficient    1
#          Emma       7     10          7        8.0      8.5       1          Good at Quant  good          1
#          Levi       7     8           7        7.0      7.5       1          Good at Quant  Sufficient    1
#          Liam       10    5           10       8.0      7.5       1          Good at Quant  good          1
#          Noah       6     6           5        6.0      6.0       1          Bad at Quant   Sufficient    1
# ...

# %%
grouped_1.describe()
# Out:
#          math                                               statistics  \
#         count      mean       std  min  25%  50%  75%   max      count
# status1
# fail      1.0  5.000000       NaN  5.0  5.0  5.0  5.0   5.0        1.0
# pass     11.0  7.363636  1.566699  5.0  6.5  7.0  8.0  10.0       11.0
#
#                    ... average2      status1.1                                \
#              mean  ...      75%  max     count mean  std  min  25%  50%  75%
# status1            ...
# fail     6.000000  ...      5.5  5.5       1.0  0.0  NaN  0.0  0.0  0.0  0.0
# pass     7.181818  ...      7.5  8.5      11.0  1.0  0.0  1.0  1.0  1.0  1.0
#
#
#          max
# status1
# fail     0.0
# pass     1.0
#
# [2 rows x 48 columns]

# %%
grouped_1.mean()
# Out:
# <ipython-input-172-aedc4bccd316>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped_1.mean()
#              math  statistics   physics   average  average2  status1.1
# status1
# fail     5.000000    6.000000  5.000000  5.000000  5.500000        0.0
# pass     7.363636    7.181818  7.454545  7.181818  7.272727        1.0

# %%
grouped_2.mean()
# Out:
# <ipython-input-174-e60dbc8bf316>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped_2.mean()
#                    math  statistics  physics   average  average2  status1.1
# statusc
# Bad at Quant   5.800000    6.800000      7.6  6.600000  6.300000        0.8
# Good at Quant  8.142857    7.285714      7.0  7.285714  7.714286        1.0

# %%
import matplotlib.pyplot as plt

# Counts
counts = db['status1'].value_counts()
# Create bar plot
ax = counts.plot.bar('status1', rot=0, color='red')
# Labels
ax.set_title('Datos')
ax.set_ylabel('Count')
ax.set_xlabel('status1')

plt.show()

# %%
ct = pd.crosstab(db['status1'], db['math'])
ct
# Out:
# math     5   6   7   8   10
# status1
# fail      1   0   0   0   0
# pass      1   2   4   2   2

# %%
grouped_1.mean()
# Out:
# <ipython-input-160-aedc4bccd316>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped_1.mean()
#              math  statistics   physics   average  average2  status1.1
# status1
# fail     5.000000    6.000000  5.000000  5.000000  5.500000        0.0
# pass     7.363636    7.181818  7.454545  7.181818  7.272727        1.0

# %%
grouped_1["math"].mean()
# Out:
# status1
# fail    5.000000
# pass    7.363636
# Name: math, dtype: float64

# %%
grouped_2=db.groupby("status2")

# %%
grouped_2.value_counts()
# Out:
# status2     name       math  statistics  physics  average  average2  status1  status1.1  status3
# Sufficient  Amelia     8     7           7        7.0      7.5       pass     1          Good at Quant    1
#             Charlotte  7     7           8        7.0      7.0       pass     1          Bad at Quant     1
#             Levi       7     8           7        7.0      7.5       pass     1          Good at Quant    1
#             Noah       6     6           5        6.0      6.0       pass     1          Bad at Quant     1
#             Olivia     8     7           7        7.0      7.5       pass     1          Good at Quant    1
#             Olivier    5     7           10       7.0      6.0       pass     1          Bad at Quant     1
#             Sophia     10    6           5        7.0      8.0       pass     1          Good at Quant    1
#             William    7     8           6        7.0      7.5       pass     1          Good at Quant    1
# ...

# %%
grouped_2.mean()
# Out:
# <ipython-input-164-e60dbc8bf316>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped_2.mean()
#                 math  statistics  physics  average  average2  status1.1
# status2
# Sufficient  7.250000    7.000000    6.875    6.875  7.125000        1.0
# fail        5.000000    6.000000    5.000    5.000  5.500000        0.0
# good        7.666667    7.666667    9.000    8.000  7.666667        1.0

# %%
grouped_2["math"].mean()
# Out:
# status2
# Sufficient    7.250000
# fail          5.000000
# good          7.666667
# Name: math, dtype: float64
